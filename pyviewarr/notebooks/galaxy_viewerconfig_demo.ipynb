# %%
from astropy.io import fits
from astropy.utils.data import get_pkg_data_filename

filename = get_pkg_data_filename('galactic_center/gc_msx_e.fits')
data = fits.getdata(filename)

# %%
import pyviewarr

# %%
viewer = pyviewarr.viewarr(data, stretch='log', cmap='magma')
viewer

# %%
config = viewer.get_viewer_config()
import dataclasses
dataclasses.asdict(config)
# Out:
# {'contrast': 1.0,
#  'bias': 0.5,
#  'stretch': 'log',
#  'zoom': 1.0,
#  'cmap': 'magma',
#  'colormap_reversed': False,
#  'vmin': -1.803424090063288e-07,
#  'vmax': 0.0028928708197781816,
#  'xlim': (0.0, 149.0),
#  'ylim': (0.0, 149.0),
#  'rotation': 0.0,
#  'pivot': (74.0, 74.0),
#  'show_pivot_marker': False,
#  'markers': [],
#  'on_shift_click': None,
#  'overlay_message': ''}

# %%
viewer2 = pyviewarr.show(data, viewer_config=config)
viewer2
